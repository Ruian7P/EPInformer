# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys

# %%
motif_path = "/home/ruian7p/Projects/EPInformer/data/promoter_2k_motif_hits.tsv"

df = pd.read_csv(
motif_path,
sep="\t",
comment="#",
index_col=0,
engine="python" 
)

print(df.shape)
display(df.head())
# Out:
# (18377, 1796)
#                  GM.5.0.Sox.0001  GM.5.0.Homeodomain.0001  GM.5.0.Mixed.0001  \
# ENSG00000000003                0                        0                  0
# ENSG00000000005                0                        0                  0
# ENSG00000000419                0                        0                  0
# ENSG00000000457                0                        0                  0
# ENSG00000000460                0                        0                  0
#
#                  GM.5.0.Nuclear_receptor.0001  GM.5.0.Mixed.0002  \
# ENSG00000000003                             0                  0
# ENSG00000000005                             0                  0
# ENSG00000000419                             0                  0
# ENSG00000000457                             0                  0
# ENSG00000000460                             0                  0
#
#                  GM.5.0.Nuclear_receptor.0002  GM.5.0.bHLH.0001  \
# ...

# %%
# check each motif count
motif_counts = df.sum(axis=0)
print(motif_counts)
# Out:
# GM.5.0.Sox.0001                    0
# GM.5.0.Homeodomain.0001          105
# GM.5.0.Mixed.0001               3391
# GM.5.0.Nuclear_receptor.0001     180
# GM.5.0.Mixed.0002                  0
#                                 ...
# GM.5.0.C2H2_ZF.0316              375
# GM.5.0.C2H2_ZF.0317              102
# GM.5.0.Ets.0049                  287
# GM.5.0.Unknown.0208               80
# GM.5.0.Homeodomain_POU.0026       47
# Length: 1796, dtype: int64

# %%
# bin motif counts
labels = ['0','1-50', '50-100', '100-150', '150-200', '200-250', '250-300', '300-350', '350-400', '400-450', '450-500', '500+']
bins = [0, 1, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, np.inf]
binned_counts = pd.cut(motif_counts, bins=bins, labels=labels).value_counts().sort_index()
print(binned_counts)
# Out:
# 0            2
# 1-50        72
# 50-100     228
# 100-150    175
# 150-200    111
# 200-250     73
# 250-300     65
# 300-350     55
# 350-400     54
# 400-450     26
# 450-500     27
# 500+       351
# Name: count, dtype: int64

# %%
# bin hit counts per gene
gene_counts = df.sum(axis=1)
gene_bins = [0, 1, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, np.inf]
binned_gene_counts = pd.cut(gene_counts, bins=gene_bins, labels=gene_labels).value_counts().sort_index()
print(binned_gene_counts)
# Out:
# 0                 0
# 1-10            257
# 10-50         11569
# 50-100         6447
# 100-200         104
# 200-500           0
# 500-1000          0
# 1000-2000         0
# 2000-5000         0
# 5000-10000        0
# 10000+            0
# Name: count, dtype: int64
